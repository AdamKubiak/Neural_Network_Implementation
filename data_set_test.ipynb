# %%
# ta komórka rozpakowuje archiwa zestawu danych MNIST

import sys
import gzip
import shutil
import os

if (sys.version_info > (3, 0)):
    writemode = 'wb'
else:
    writemode = 'w'

zipped_mnist = [f for f in os.listdir('./') if f.endswith('ubyte.gz')]
for z in zipped_mnist:
    with gzip.GzipFile(z, mode='rb') as decompressed, open(z[:-3], writemode) as outfile:
        outfile.write(decompressed.read()) 

import os
import struct
import numpy as np
 
def load_mnist(path, kind='train'):
    """Wczytuje dane MNIST umieszczone w katalogu roboczym"""
    labels_path = os.path.join(path, 
                               '%s-labels-idx1-ubyte' % kind)
    images_path = os.path.join(path, 
                               '%s-images-idx3-ubyte' % kind)
        
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II', 
                                 lbpath.read(8))
        labels = np.fromfile(lbpath, 
                             dtype=np.uint8)

    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack(">IIII", 
                                               imgpath.read(16))
        images = np.fromfile(imgpath, 
                             dtype=np.uint8).reshape(len(labels), 784)
        images = ((images / 255.) - .5) * 2
 
    return images, labels

# %%
X_train, y_train = load_mnist('', kind='train')
print('Rzędy: %d, Kolumny: %d' % (X_train.shape[0], X_train.shape[1]))
# Out:
# Rzędy: 60000, Kolumny: 784

# %%
X_test, y_test = load_mnist('', kind='t10k')
print('Rzędy: %d, Kolumny: %d' % (X_test.shape[0], X_test.shape[1]))
# Out:
# Rzędy: 10000, Kolumny: 784

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(10):
    img = X_train[y_train == i][0].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
# plt.savefig('rysunki/12_5.png', dpi=300)
plt.show()

# %%
import numpy as np

np.savez_compressed('mnist_scaled.npz', 
                    X_train=X_train,
                    y_train=y_train,
                    X_test=X_test,
                    y_test=y_test)

# %%
mnist = np.load('mnist_scaled.npz')
mnist.files
# Out:
# ['X_train', 'y_train', 'X_test', 'y_test']

# %%
X_train, y_train, X_valid, y_valid = [mnist[f] for f in ['X_train', 'y_train', 
                                    'X_test', 'y_test']]

del mnist

X_train.shape
# Out:
# (60000, 784)

# %%
import Neural_Network_Script as nn
import matplotlib.pyplot as plt
x = np.load('dataset\\full_numpy_bitmap_broccoli.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
x = x[:10000]
y = np.zeros(10000)
print(x1.shape)
X_train = x
y_train = y
X_valid = x1
y_valid = y1

x = np.load('dataset\\full_numpy_bitmap_banana.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,1)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,1)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)


x = np.load('dataset\\full_numpy_bitmap_angel.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,2)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,2)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

x = np.load('dataset\\full_numpy_bitmap_bicycle.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,3)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,3)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

x = np.load('dataset\\full_numpy_bitmap_sun.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,4)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,4)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

x = np.load('dataset\\full_numpy_bitmap_octopus.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,5)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,5)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

x = np.load('dataset\\full_numpy_bitmap_dolphin.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,6)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,6)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

x = np.load('dataset\\full_numpy_bitmap_scissors.npy')
x1 = x[10000:10100]
y1 = np.zeros(100)
y1 = np.add(y1,7)
x = x[:10000]
y = np.zeros(10000)


y = np.add(y,7)
X_train = np.append(X_train,x,axis = 0)
y_train = np.append(y_train,y)
X_valid = np.append(X_valid,x1,axis =0)
y_valid = np.append(y_valid,y1)

from sklearn.utils import shuffle
print(X_train.shape,y_train.shape)
print(X_valid.shape,y_valid.shape)
X_train,y_train = shuffle(X_train,y_valid)
X_valid,y_valid = shuffle(X_train,y_valid)
# Out:
# (100, 784)
# (80000, 784) (80000,)
# (800, 784) (800,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [34], line 116
#     114 print(X_train.shape,y_train.shape)
#     115 print(X_valid.shape,y_valid.shape)
# --> 116 X_train,y_train = shuffle(X_train,y_valid)
#     117 X_valid,y_valid = shuffle(X_train,y_valid)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\__init__.py:651, in shuffle(random_state, n_samples, *arrays)
#     585 def shuffle(*arrays, random_state=None, n_samples=None):
#     586     """Shuffle arrays or sparse matrices in a consistent way.
#     587
#     588     This is a convenience alias to ``resample(*arrays, replace=False)`` to do
#    (...)
#     649     resample
#     650     """
# --> 651     return resample(
#     652         *arrays, replace=False, n_samples=n_samples, random_state=random_state
#     653     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\__init__.py:537, in resample(replace, n_samples, random_state, stratify, *arrays)
#     531 elif (max_n_samples > n_samples) and (not replace):
#     532     raise ValueError(
#     533         "Cannot sample %d out of arrays with dim %d when replace is False"
#     534         % (max_n_samples, n_samples)
#     535     )
# --> 537 check_consistent_length(*arrays)
#     539 if stratify is None:
#     540     if replace:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:387, in check_consistent_length(*arrays)
#     385 uniques = np.unique(lengths)
#     386 if len(uniques) > 1:
# --> 387     raise ValueError(
#     388         "Found input variables with inconsistent numbers of samples: %r"
#     389         % [int(l) for l in lengths]
#     390     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [80000, 800]

# %%
layers = [784,100,8]
network = nn.NeuralNetwork(layers,200,0.0005,0.01,100)
network.learn(X_train, y_train, X_valid, y_valid)

#datagen.fit(X_train)
# Out:
# 200/200 | Koszt: 0.08 | Dokładność uczenia/walidacji: 89.70%/83.62%

# %%
plt.plot(range(network.epoch), network.eval_['cost'])
plt.ylabel('Koszt')
plt.xlabel('Epoki')
#plt.savefig('rysunki/12_07.png', dpi=300)
plt.show()

# %%
plt.plot(range(network.epoch), network.eval_['train_acc'], 
         label='Zestaw uczący')
plt.plot(range(network.epoch), network.eval_['valid_acc'], 
         label='Zestaw walidacyjny', linestyle='--')
plt.ylabel('Dokładność')
plt.xlabel('Epoki')
plt.legend()
#plt.savefig('rysunki/12_08.png', dpi=300)
plt.show()

# %%
y_test_pred = network.network_predict(X_valid)
acc = (np.sum(y_valid == y_test_pred)
       .astype(np.float) / X_valid.shape[0])

print('Dokładność dla danych testowych: %.2f%%' % (acc * 100.))
# Out:
# Dokładność dla danych testowych: 83.62%
# c:\Users\Adum\Desktop\Neural_Network_Doodle\Neural_Network_Implementation\Neural_Network_Script.py:9: RuntimeWarning: overflow encountered in exp
#   return 1./(1. + np.exp(-weightedInput))
# C:\Users\Adum\AppData\Local\Temp\ipykernel_4072\1289264210.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   .astype(np.float) / X_valid.shape[0])

# %%
miscl_img = X_valid[y_valid == y_test_pred][:25]
correct_lab = y_valid[y_valid == y_test_pred][:25]
miscl_lab = y_test_pred[y_valid == y_test_pred][:25]

fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(25):
    img = miscl_img[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title('%d) r: %d p: %d' % (i+1, correct_lab[i], miscl_lab[i]))

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('rysunki/12_09.png', dpi=300)
plt.show()
