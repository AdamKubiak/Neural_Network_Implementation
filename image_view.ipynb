# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
data = np.load('full_numpy_bitmap_broccoli.npy')

print(len(data))
# Out:
# 132826

# %%
fig,axe=plt.subplots(2,2,figsize = (12,8))
fig.suptitle('Przegląd zbioru danych')
axe[0,0].imshow(data[0].reshape(28,28),cmap='gray')

axe[0,0].axis('off')
axe[0,1].imshow(data[1].reshape(28,28),cmap='gray')

axe[0,1].axis('off')
axe[1,0].imshow(data[2].reshape(28,28),cmap='gray')

axe[1,0].axis('off')
axe[1,1].imshow(data[27530].reshape(28,28),cmap='gray')

axe[1,1].axis('off')
# Out:
# (-0.5, 27.5, 27.5, -0.5)
